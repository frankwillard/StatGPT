# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('590.csv')
df.head()
# Out:
#    Unnamed: 0               Player  Eligible       Position  Hall_of_Fame  \
# 0           0       Alaa Abdelnaby         1   PowerForward             0
# 1           1      Zaid Abdul-Aziz         1         Center             0
# 2           2  Kareem Abdul-Jabbar         1         Center             1
# 3           3   Mahmoud Abdul-Rauf         1     PointGuard             0
# 4           4    Tariq Abdul-Wahad         1  ShootingGuard             0
#
#    MVP  Finals_MVP  NBA_Champ  All_NBA  All_Defensive  ...  TS%_advanced  \
# 0    0           0          0        0              0  ...         0.532
# 1    0           0          0        0              0  ...         0.479
# 2    6           2          6       15             11  ...         0.592
# 3    0           0          0        0              0  ...         0.506
# 4    0           0          0        0              0  ...         0.467
#
#    OWS_advanced  DWS_advanced  WS_advanced  WS/48_advanced  OBPM_advanced  \
# ...

# %%
# hall of fame data

df = df[["Player", "PTS_per_game", "TRB_per_game" , "AST_per_game" , "STL_per_game" ,"BLK_per_game", "Hall_of_Fame"]]

df.rename(columns={'PTS_per_game': 'Points', 'TRB_per_game': 'Rebounds', 'AST_per_game': 'Assists', 'STL_per_game': 'Steals', 'BLK_per_game': 'Blocks', "Hall_of_Fame" : "hof"}, inplace=True)


# Convert all columns to integer type
df = df.astype(float, errors='ignore')


cond1 = (df["Points"] < 99) & (df["Rebounds"] < 99) & (df["Assists"] < 99) & (df["Steals"] < 99) & (df["Blocks"] < 99)

cond2 = (df["Points"] > 0) & (df["Rebounds"] > 0) & (df["Assists"] > 0) & (df["Steals"] > 0) & (df["Blocks"] > 0)



df = df[cond1]
df = df[cond2]

df.to_csv('hof.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-948eab97a606> in <cell line: 3>()
#       1 # hall of fame data
#       2
# ----> 3 df = df[["Player", "PTS_per_game", "TRB_per_game" , "AST_per_game" , "STL_per_game" ,"BLK_per_game", "Hall_of_Fame"]]
#       4
#       5 df.rename(columns={'PTS_per_game': 'Points', 'TRB_per_game': 'Rebounds', 'AST_per_game': 'Assists', 'STL_per_game': 'Steals', 'BLK_per_game': 'Blocks', "Hall_of_Fame" : "hof"}, inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# ...

# %%
print(df["Points"].mean(), df["Rebounds"].mean(), df["Assists"].mean(), df["Steals"].mean(), df["Blocks"].mean())
# Out:
# 7.647106369220821 3.4206918849013905 1.6530229550598126 0.6223731005496282 0.3876172001293242

# %%
player_stats = pd.read_csv('players_stats.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-59e10b009607> in <cell line: 1>()
# ----> 1 player_stats = pd.read_csv('players_stats.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
# Load in dataset of previous seasons, include only teams who made the playoffs
historic_dataset = pd.read_csv("https://raw.githubusercontent.com/milesfking/NBA-Champion-Model/main/data/nba_team_advanced_data.csv")
historic_dataset = historic_dataset[historic_dataset["Playoffs"] == "Y"]

# %%
historic_dataset = historic_dataset.drop(columns=['Losing_season', 'Arena', 'L', 'W', 'PW', 'PL', 'Attend.', 'OeFG%', 'OTOV%', 'ORB%', 'OFT/FGA',
       'DeFG%', 'DTOV%', 'DRB%', 'DFT/FGA', 'Pace', 'FTr', '3PAr',])

print(historic_dataset.head())
# Out:
#      Year                 Team   Age   MOV   SOS   SRS   ORtg   DRtg  NRtg  \
# 1  1990.0       Boston Celtics  30.2  3.99 -0.76  3.23  112.0  107.9   4.1
# 3  1990.0        Chicago Bulls  26.1  3.26 -0.51  2.74  112.3  109.0   3.3
# 4  1990.0  Cleveland Cavaliers  26.1 -0.30 -0.31 -0.62  106.9  107.2  -0.3
# 5  1990.0     Dallas Mavericks  29.2  0.07  0.35  0.42  107.2  107.2   0.0
# 6  1990.0       Denver Nuggets  29.5  1.41  0.15  1.56  108.0  106.7   1.3
#
#      TS% Playoffs      W/L% Champion won_last won_last_3
# 1  0.557        Y  0.634146        N        N          N
# 3  0.559        Y  0.670732        N        N          N
# 4  0.529        Y  0.512195        N        N          N
# 5  0.536        Y  0.573171        N        N          N
# 6  0.523        Y  0.524390        N        N          N

# %%
historic_dataset.to_csv(r'historic_dataset_playoffs.csv', index=False)
